# %%
from google.colab import drive
drive.mount('/content/gdrive')
# install below if you do not have texttable package
# !pip install texttable

from collections import defaultdict
import copy
import datetime
import itertools
from itertools import combinations
import re
import math
from pprint import pprint
import random
from random import randint
import warnings
from texttable import Texttable
warnings.filterwarnings("ignore", category=UserWarning) 

import numpy as np
from numpy import arange
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib import gridspec
from scipy.stats import wasserstein_distance
from sklearn.metrics import f1_score
from sklearn import preprocessing
import pandas as pd
import io
import os

verbose = False
plot_chart = True
# Out:
# Mounted at /content/gdrive
# ...

# %% [markdown]
# servers.py

# %%
#Import csv files
HC_HighIID = pd.read_csv("/content/gdrive/My Drive/HC_HighIID.csv")
HC_LowIID = pd.read_csv("/content/gdrive/My Drive/HC_LowIID.csv")
HC_ModIID = pd.read_csv("/content/gdrive/My Drive/HC_ModIID.csv")
MNIST_LowIID = pd.read_csv("/content/gdrive/My Drive/MNIST_LowIID.csv")
MNIST_ModIID = pd.read_csv("/content/gdrive/My Drive/MNIST_ModIID.csv")

HC_HighIID = pd.DataFrame(HC_HighIID)
HC_ModIID = pd.DataFrame(HC_ModIID)
HC_LowIID = pd.DataFrame(HC_LowIID)

MNIST_ModIID = pd.DataFrame(MNIST_ModIID)
MNIST_LowIID = pd.DataFrame(MNIST_LowIID)

# %%
# Chart Results
plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(10,7))
plt.title("Low IID MNIST", fontsize=20)
plt.xlabel("Communication Rounds")
plt.ylabel("F1 Accuracy")

# Change Dataset
HC_HighIID_hdr = list(HC_HighIID.columns.values.tolist())
HC_ModIID_hdr = list(HC_ModIID.columns.values.tolist())
HC_LowIID_hdr = list(HC_LowIID.columns.values.tolist())

MNIST_ModIID_hdr = list(MNIST_ModIID.columns.values.tolist())
MNIST_LowIID_hdr = list(MNIST_LowIID.columns.values.tolist())

# Change these below with column names
labels = [MNIST_LowIID_hdr[2], MNIST_LowIID_hdr[18]]
plt.plot(MNIST_LowIID.iloc[:, [0]], MNIST_LowIID.iloc[:, [2]])
plt.plot(MNIST_LowIID.iloc[:, [0]], MNIST_LowIID.iloc[:, [18]])

plt.legend(labels,loc="lower center", frameon=False, prop={'size': 9}, bbox_to_anchor=(0.5, -0.3))
plt.show()

# %%
# Bar Chart for Slides
#IID Data
import matplotlib.pyplot as plt
import numpy as np

labels = ['MNIST', 'CIFAR-10', 'HC']
# Low IID
low_batch = [98.425, 48.9, 80.125]
high_batch = [98.375, 66.95, 82.75]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, low_batch, width, label='Low Batch')
rects2 = ax.bar(x + width/2, high_batch, width, label='High Batch')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('F1 Accuracy')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

fig.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-786801be7c38> in <module>()
#      22 ax.legend()
#      23
# ---> 24 ax.bar_label(rects1, padding=1)
#      25 ax.bar_label(rects2, padding=1)
#      26
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %%
# Bar Chart for Slides
#IID Data
import matplotlib.pyplot as plt
import numpy as np

labels = ['MNIST', 'CIFAR-10', 'HC']
# Low IID
low_batch = [99, 77.4, 74.2]
high_batch = [99.15, 82.4, 73.3]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, low_batch, width, label='Low Batch')
rects2 = ax.bar(x + width/2, high_batch, width, label='High Batch')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('F1 Accuracy')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

fig.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-83806f5951ac> in <module>()
#      22 ax.legend()
#      23
# ---> 24 ax.bar_label(rects1, padding=1)
#      25 ax.bar_label(rects2, padding=1)
#      26
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %%
# CIFAR updated moving average
# Low IID
low_batch = [99, 51.85, 74.2]
high_batch = [99.15, 68.4, 73.3]

# Moderate IID
low_batch = [98.675, 49.28, 80.2]
high_batch = [98.825, 64.03, 81.1]

# High IID
low_batch = [98.425, 48.9, 80.125]
high_batch = [98.375, 66.95, 82.75]

# %%
# Low IID
low_batch = [99, 77.4, 74.2]
high_batch = [99.15, 82.4, 73.3]

# Moderate IID
low_batch = [98.675, 52.725, 80.2]
high_batch = [98.825, 67.975, 81.1]

# High IID
low_batch = [98.425, 53.775, 80.125]
high_batch = [98.375, 70.05, 82.75]

# %%
# FINAL REPORT CHARTS
# For Batch Size Charts HC stable aggregators, impact of batch size
# on a variety of different aggregators
# Low IID by aggregator and batch size (keep epoch constant)

plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(10,7))
plt.title("Low IID - SCAFFOLD", fontsize=20)
plt.xlabel("Communication Rounds")
plt.ylabel("F1 Accuracy")

# Change Dataset
HC_HighIID_hdr = list(HC_HighIID.columns.values.tolist())
HC_ModIID_hdr = list(HC_ModIID.columns.values.tolist())
HC_LowIID_hdr = list(HC_LowIID.columns.values.tolist())

MNIST_ModIID_hdr = list(MNIST_ModIID.columns.values.tolist())
MNIST_LowIID_hdr = list(MNIST_LowIID.columns.values.tolist())

# Change these below with column names
labels = [HC_LowIID_hdr[47], HC_LowIID_hdr[45]]
plt.plot(HC_LowIID.iloc[:, [0]], HC_LowIID.iloc[:, [47]])
plt.plot(HC_LowIID.iloc[:, [0]], HC_LowIID.iloc[:, [45]])

plt.legend(labels,loc="lower center", frameon=False, prop={'size': 9}, bbox_to_anchor=(0.5, -0.3))
plt.show()
